# %% [markdown]
# # CIFAR10 Classification Problem

# %% [markdown]
#  **Exercise objectives**
#
# *  Implement a CNN to solve a **`10-class classification problem`**
#
# *  Enhance the CNN's performance with **`Data Augmentation Techniques`**
#
# *  Experiment with **`GPUs to Accelerate Image Processing using Google Colab`**
#
# <hr>

# %% [markdown]
# ##  Google Colab Setup

# %% [markdown]
# If you are planning to use Google Colab (which is strongly recommended for this challenge), there is a few things you need to take care of first so that you can run everything properly.
#
# * If you want to get started, follow these four steps.
# * You can also read Davy's tutorial on Kitt 👉 [Introduction to Google Colab](https://kitt.lewagon.com/knowledge/tutorials/data_google_colab)

# %% [markdown]
# ### Step 1: Upload the Challenge Folder to Google Drive and Open it in Colab

# %% [markdown]
# If you want Google Colab to be able to run this notebook, you need to ***upload all the necessary files to your Google Drive***.
#
# To do this, simply:
# 1. Access your [Google Drive](https://drive.google.com/)
# 2. Go into the `Colab Notebooks folder`
# 3. Drag-and-drop this `challenge's folder` into it
# 4. Right-click the notebook file and select `Open with` $\rightarrow$ `Google Colaboratory`

# %% [markdown]
# ### Step 2: Mount Google Drive

# %% [markdown]
# The previous was necessary but not enough. For security purposes, Google Colab and Google Drive are NOT connected even if they belong to the same Google Account
#
# We need to ***mount the main directory of the Google Drive associated with the account being used for Colab***.
#
# *Note: if you're getting errors when authenticating, try to do it in Google Chrome, as other browsers tend to experience issues.*

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
#  On the left sidebar, there is a  folder icon.
# * If you click on it, you should now see a folder called `drive/MyDrive`. This is your Google Drive and all its content!

# %% [markdown]
# ### Step 3: Navigate to the Challenge Directory

# %% [markdown]
# One more thing: we need to  this notebook in the context of the challenge's folder.
#
# Simply run the cell down below.

# %%
import os

# os.chdir allows you to change directories, like cd in the Terminal
os.chdir('/content/drive/MyDrive/Colab Notebooks/data-cifar-classification')

# %% [markdown]
# ### Step 4: Toggle GPU Acceleration

# %% [markdown]
# As a last step, we should take advantage of Google Colab by enabling GPU acceleration for our notebook.
#
# You can do it by navigating through the menu bar:
#
# `Runtime` $\rightarrow$ `Change runtime type` $\rightarrow$ `Hardware accelerator`
#
# and select "GPU" from the dropdown menu.

# %% [markdown]
# 🚀 You are now ready to start, proceed with the challenge! 🚀

# %% [markdown]
# ## (1) Loading the CIFAR10 Dataset

# %% [markdown]
#  **Question: Loading the CIFAR10 Dataset**
#
#
# *  We took care of the `data loading and preprocessing` for you.
# *  Just run the following cell and make sure you understand the code.

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np

(images_train, labels_train), (images_test, labels_test) = cifar10.load_data()

labels = ['airplane', 
          'automobile',
          'bird',
          'cat',
          'deer',
          'dog',
          'frog',
          'horse',
          'ship',
          'truck']

print(images_train.shape, images_test.shape)
unique, counts = np.unique(labels_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# {0: 5000,
#  1: 5000,
#  2: 5000,
#  3: 5000,
#  4: 5000,
#  5: 5000,
#  6: 5000,
#  7: 5000,
#  8: 5000,
#  9: 5000}

# %% [markdown]
# ### (1.1) Working on a smaller dataset?

# %% [markdown]
#  **Question about the training size**
#
# * It will probably take a very long time to train a model on $50 000$ images m...
# *  **Always start with a subsample to iterate quickly** before scaling up!
# * Run the next cell where we are reducing the dataset size by `reduction_factor = 10`. Don't try to increase it unless we ask you to do so...

# %%
# Considering only 1/10th of the 50_000 images
reduction_factor = 10

# Choosing the random indices of small train set and small test set
idx_train =  np.random.choice(len(images_train), round(len(images_train)/reduction_factor), replace=False)
idx_test =  np.random.choice(len(images_test), round(len(images_test)/reduction_factor), replace=False)

# Collecting the two subsamples images_train_small and images_test_small from images_train and images_test
images_train_small = images_train[idx_train]
images_test_small = images_test[idx_test]
# and their corresponding labels
labels_train_small = labels_train[idx_train]
labels_test_small = labels_test[idx_test]

print("------------------ Before -----------------")
print(images_train.shape, images_test.shape)

print("")

print("--- After applying the reduction factor ---")
print(images_train_small.shape, images_test_small.shape)

print("")
print("-"*43)

unique, counts = np.unique(labels_train_small, return_counts=True)
dict(zip(unique, counts))
# Out:
# ------------------ Before -----------------
# (50000, 32, 32, 3) (10000, 32, 32, 3)
#
# --- After applying the reduction factor ---
# (5000, 32, 32, 3) (1000, 32, 32, 3)
#
# -------------------------------------------
# {0: 479,
#  1: 538,
#  2: 532,
#  3: 468,
#  4: 491,
#  5: 501,
#  6: 468,
#  7: 488,
#  8: 509,
#  9: 526}

# %%
# Let's plot few images to see what they look like
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
for i in range(6):
    plt.subplot(1,6, i+1)
    img = images_train[i]
    label = labels_train[i][0]
    plt.imshow(img)
    plt.title(labels[label])

# %% [markdown]
# ### (1.2) Image preprocesing

# %% [markdown]
#  As usual, let's:
# - normalize the pixels' intensities between 0 and 1
# - turn the `labels_train` and `labels_test` into "one-hot-encoded" targets that we will call respectively `y_train` and `y_test`

# %%
### Normalizing pixels' intensities
X_train = images_train / 255.
X_train_small = images_train_small / 255.
X_test = images_test / 255.
X_test_small = images_test_small / 255.

### Encoding the labels
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(labels_train, 10)
y_train_small = to_categorical(labels_train_small, 10)
y_test = to_categorical(labels_test, 10)
y_test_small = to_categorical(labels_test_small, 10)

# %% [markdown]
# ## (2) Iterate on your CNN architecture using your small training set

# %% [markdown]
#  **Question**
#
# 1. Define the CNN architecture of your choice in an `initialize_model()` function:
# 2. Compile your model in a `compile_model()` method:
# 3. Fit your CNN only on the `small training set` and save the training information in an `history` variable
# ---

# %%
def initialize_model():
    '''instanciate and return the CNN architecture of your choice with less than 150,000 params'''
    # YOUR CODE HERE
    pass

# %%
def compile_model(model):
    '''return a compiled model suited for the CIFAR-10 task'''
    # YOUR CODE HERE
    pass

# %%
########################
# A POSSIBLE ANSWER    #
########################

from tensorflow.keras import Sequential, layers
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense

def initialize_model():
    
    model = Sequential()
    
    model.add(Conv2D(16, (3, 3), activation = 'relu', padding = 'same', input_shape=(32, 32, 3)))
    model.add(MaxPooling2D((2, 2)))
    
    model.add(Dropout(0.2))
    
    model.add(Conv2D(32, (3, 3), activation = 'relu', padding = 'same'))
    model.add(MaxPooling2D((2, 2)))
    
    model.add(Dropout(0.2))
    
    model.add(Conv2D(64, (2, 2), activation = 'relu', padding = 'same'))
    model.add(Dropout(0.3))
    model.add(MaxPooling2D((2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation = 'relu'))
    model.add(Dropout(0.4))
    model.add(Dense(10, activation = 'softmax'))
    
    return model

# %%
model = initialize_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 16)        448
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 16)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 32)          0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 64)          8256
#
#  dropout_2 (Dropout)         (None, 8, 8, 64)          0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 100)               102500
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 116,854
# Trainable params: 116,854
# Non-trainable params: 0
# _________________________________________________________________
# 2022-09-14 17:41:13.538994: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from tensorflow.keras import optimizers

def compile_model(model):
    model.compile(loss = 'categorical_crossentropy',
                  optimizer = 'adam',
                  metrics = ['accuracy'])
    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping

model_small = initialize_model()
model_small = compile_model(model)

es = EarlyStopping(patience = 5, verbose = 2)

history_small = model_small.fit(X_train_small, y_train_small, 
                    validation_split = 0.3,
                    callbacks = [es], 
                    epochs = 100, 
                    batch_size = 64)
# Out:
# Epoch 1/100
# 55/55 [==============================] - 2s 31ms/step - loss: 2.2895 - accuracy: 0.1223 - val_loss: 2.2474 - val_accuracy: 0.1567
# Epoch 2/100
# 55/55 [==============================] - 2s 29ms/step - loss: 2.1498 - accuracy: 0.1980 - val_loss: 2.1264 - val_accuracy: 0.2973
# Epoch 3/100
# 55/55 [==============================] - 2s 31ms/step - loss: 2.0532 - accuracy: 0.2446 - val_loss: 1.9976 - val_accuracy: 0.3167
# Epoch 4/100
# 55/55 [==============================] - 2s 30ms/step - loss: 1.8991 - accuracy: 0.3074 - val_loss: 1.9037 - val_accuracy: 0.3633
# Epoch 5/100
# 55/55 [==============================] - 2s 29ms/step - loss: 1.8360 - accuracy: 0.3097 - val_loss: 1.9034 - val_accuracy: 0.3320
# Epoch 6/100
# 55/55 [==============================] - 2s 30ms/step - loss: 1.7336 - accuracy: 0.3511 - val_loss: 1.7448 - val_accuracy: 0.4187
# Epoch 7/100
# 55/55 [==============================] - 2s 29ms/step - loss: 1.7015 - accuracy: 0.3777 - val_loss: 1.7060 - val_accuracy: 0.4307
# Epoch 8/100
# 55/55 [==============================] - 2s 28ms/step - loss: 1.6667 - accuracy: 0.3731 - val_loss: 1.6587 - val_accuracy: 0.4313
# Epoch 9/100
# 55/55 [==============================] - 2s 28ms/step - loss: 1.6214 - accuracy: 0.3911 - val_loss: 1.6220 - val_accuracy: 0.4553
# Epoch 10/100
# 55/55 [==============================] - 2s 28ms/step - loss: 1.5627 - accuracy: 0.4214 - val_loss: 1.5578 - val_accuracy: 0.4713
# Epoch 11/100
# 55/55 [==============================] - 2s 28ms/step - loss: 1.5579 - accuracy: 0.4203 - val_loss: 1.6356 - val_accuracy: 0.4380
# Epoch 12/100
# 55/55 [==============================] - 2s 28ms/step - loss: 1.5415 - accuracy: 0.4397 - val_loss: 1.5664 - val_accuracy: 0.4593
# Epoch 13/100
# 55/55 [==============================] - 2s 29ms/step - loss: 1.5217 - accuracy: 0.4431 - val_loss: 1.5078 - val_accuracy: 0.4847
# Epoch 14/100
# 55/55 [==============================] - 2s 28ms/step - loss: 1.4588 - accuracy: 0.4711 - val_loss: 1.4882 - val_accuracy: 0.4833
# Epoch 15/100
# 55/55 [==============================] - 2s 28ms/step - loss: 1.4650 - accuracy: 0.4660 - val_loss: 1.4582 - val_accuracy: 0.4953
# Epoch 16/100
# 55/55 [==============================] - 2s 28ms/step - loss: 1.4349 - accuracy: 0.4663 - val_loss: 1.4976 - val_accuracy: 0.4940
# Epoch 17/100
# 55/55 [==============================] - 2s 28ms/step - loss: 1.4110 - accuracy: 0.4877 - val_loss: 1.4311 - val_accuracy: 0.4947
# Epoch 18/100
# 55/55 [==============================] - 2s 28ms/step - loss: 1.3731 - accuracy: 0.4917 - val_loss: 1.4272 - val_accuracy: 0.4873
# Epoch 19/100
# 55/55 [==============================] - 2s 28ms/step - loss: 1.3858 - accuracy: 0.4931 - val_loss: 1.4031 - val_accuracy: 0.5187
# Epoch 20/100
# 55/55 [==============================] - 2s 28ms/step - loss: 1.3572 - accuracy: 0.5011 - val_loss: 1.3798 - val_accuracy: 0.5160
# Epoch 21/100
# 55/55 [==============================] - 2s 29ms/step - loss: 1.3353 - accuracy: 0.5154 - val_loss: 1.4034 - val_accuracy: 0.5000
# Epoch 22/100
# 55/55 [==============================] - 2s 30ms/step - loss: 1.3359 - accuracy: 0.5031 - val_loss: 1.3888 - val_accuracy: 0.5267
# Epoch 23/100
# 55/55 [==============================] - 2s 30ms/step - loss: 1.3038 - accuracy: 0.5191 - val_loss: 1.3556 - val_accuracy: 0.5313
# Epoch 24/100
# 55/55 [==============================] - 2s 29ms/step - loss: 1.2876 - accuracy: 0.5329 - val_loss: 1.3539 - val_accuracy: 0.5307
# Epoch 25/100
# 55/55 [==============================] - 2s 29ms/step - loss: 1.2924 - accuracy: 0.5300 - val_loss: 1.3835 - val_accuracy: 0.5147
# Epoch 26/100
# 55/55 [==============================] - 2s 29ms/step - loss: 1.2757 - accuracy: 0.5303 - val_loss: 1.3507 - val_accuracy: 0.5287
# Epoch 27/100
# 55/55 [==============================] - 2s 29ms/step - loss: 1.2543 - accuracy: 0.5377 - val_loss: 1.3498 - val_accuracy: 0.5380
# Epoch 28/100
# 55/55 [==============================] - 2s 29ms/step - loss: 1.2654 - accuracy: 0.5357 - val_loss: 1.3245 - val_accuracy: 0.5300
# Epoch 29/100
# 55/55 [==============================] - 2s 30ms/step - loss: 1.2470 - accuracy: 0.5509 - val_loss: 1.3065 - val_accuracy: 0.5333
# Epoch 30/100
# 55/55 [==============================] - 2s 29ms/step - loss: 1.2076 - accuracy: 0.5511 - val_loss: 1.2809 - val_accuracy: 0.5460
# Epoch 31/100
# 55/55 [==============================] - 2s 30ms/step - loss: 1.2022 - accuracy: 0.5529 - val_loss: 1.2861 - val_accuracy: 0.5427
# Epoch 32/100
# 55/55 [==============================] - 2s 29ms/step - loss: 1.1943 - accuracy: 0.5634 - val_loss: 1.3077 - val_accuracy: 0.5473
# Epoch 33/100
# 55/55 [==============================] - 2s 29ms/step - loss: 1.1980 - accuracy: 0.5646 - val_loss: 1.3187 - val_accuracy: 0.5400
# Epoch 34/100
# 55/55 [==============================] - 2s 29ms/step - loss: 1.1772 - accuracy: 0.5706 - val_loss: 1.3003 - val_accuracy: 0.5273
# Epoch 35/100
# 55/55 [==============================] - 2s 29ms/step - loss: 1.1748 - accuracy: 0.5714 - val_loss: 1.2990 - val_accuracy: 0.5393
# Epoch 00035: early stopping

# %% [markdown]
#  **Question: History of your training**
#
# Run the following function on the previous history
# _(keep the default arguments, these are intended for future plots in the notebook)_

# %%
def plot_history(history, title='', axs=None, exp_name=""):
    if axs is not None:
        ax1, ax2 = axs
    else:
        f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    
    if len(exp_name) > 0 and exp_name[0] != '_':
        exp_name = '_' + exp_name
    ax1.plot(history.history['loss'], label = 'train' + exp_name)
    ax1.plot(history.history['val_loss'], label = 'val' + exp_name)
    ax1.set_ylim(0., 2.2)
    ax1.set_title('loss')
    ax1.legend()

    ax2.plot(history.history['accuracy'], label='train accuracy'  + exp_name)
    ax2.plot(history.history['val_accuracy'], label='val accuracy'  + exp_name)
    ax2.set_ylim(0.25, 1.)
    ax2.set_title('Accuracy')
    ax2.legend()
    return (ax1, ax2)

# %%
plot_history(history_small)
plt.show()

# %% [markdown]
#  **Question: Evaluating your CNN**
#
# * Evaluate your model on the test data and compare it with a baseline accuracy.
# * Are you satisfied with this performance?
# * Look at the `PRO TIPS` above and iterate a bit if you want to improve your performance!

# %%
res = model_small.evaluate(X_test_small, y_test_small, verbose = 0)

print(f'The accuracy is {res[1]*100:.1f}% compared to a chance level of {1./len(labels)*100}%')
# Out:
# The accuracy is 52.0% compared to a chance level of 10.0%

# %% [markdown]
# ## (3) Increase the size of your training data

# %% [markdown]
#  **Question: train your model on the full dataset**
#
# - Switch to **Colab** if you haven't done it before
# - Make sure to use the **GPU acceleration** by clicking on `Runtime` $\rightarrow$ `Change runtime` $\rightarrow$ `GPU`
#
#  Training neural networks on images (in each batch) can be parallelized, and this **`parallelization procedure`** can be done on **`GPU`**.
#
# ---

# %%
# %%time
from tensorflow.keras.callbacks import EarlyStopping

model = initialize_model()
model = compile_model(model)

es = EarlyStopping(patience = 5)

history = model.fit(X_train, y_train, 
                    validation_split = 0.3,
                    callbacks = [es], 
                    epochs = 100, 
                    batch_size = 64,
                   verbose = 1)
# Out:
# Epoch 1/100
# 547/547 [==============================] - 16s 28ms/step - loss: 1.9245 - accuracy: 0.2822 - val_loss: 1.6691 - val_accuracy: 0.4309
# Epoch 2/100
# 547/547 [==============================] - 16s 29ms/step - loss: 1.6113 - accuracy: 0.4069 - val_loss: 1.4999 - val_accuracy: 0.4780
# Epoch 3/100
# 547/547 [==============================] - 15s 28ms/step - loss: 1.4947 - accuracy: 0.4537 - val_loss: 1.4175 - val_accuracy: 0.5041
# Epoch 4/100
# 547/547 [==============================] - 16s 29ms/step - loss: 1.4175 - accuracy: 0.4824 - val_loss: 1.3117 - val_accuracy: 0.5474
# Epoch 5/100
# 547/547 [==============================] - 16s 29ms/step - loss: 1.3583 - accuracy: 0.5088 - val_loss: 1.2504 - val_accuracy: 0.5745
# Epoch 6/100
# 547/547 [==============================] - 16s 29ms/step - loss: 1.3110 - accuracy: 0.5262 - val_loss: 1.1925 - val_accuracy: 0.5853
# Epoch 7/100
# 547/547 [==============================] - 16s 29ms/step - loss: 1.2754 - accuracy: 0.5412 - val_loss: 1.1751 - val_accuracy: 0.5977
# Epoch 8/100
# 547/547 [==============================] - 16s 29ms/step - loss: 1.2452 - accuracy: 0.5525 - val_loss: 1.1284 - val_accuracy: 0.6165
# Epoch 9/100
# 547/547 [==============================] - 16s 29ms/step - loss: 1.2139 - accuracy: 0.5653 - val_loss: 1.0983 - val_accuracy: 0.6263
# Epoch 10/100
# 547/547 [==============================] - 16s 28ms/step - loss: 1.1780 - accuracy: 0.5773 - val_loss: 1.0608 - val_accuracy: 0.6353
# Epoch 11/100
# 547/547 [==============================] - 16s 29ms/step - loss: 1.1676 - accuracy: 0.5847 - val_loss: 1.0167 - val_accuracy: 0.6533
# Epoch 12/100
# 547/547 [==============================] - 16s 29ms/step - loss: 1.1431 - accuracy: 0.5930 - val_loss: 1.0557 - val_accuracy: 0.6441
# Epoch 13/100
# 547/547 [==============================] - 16s 29ms/step - loss: 1.1260 - accuracy: 0.6001 - val_loss: 1.0331 - val_accuracy: 0.6607
# Epoch 14/100
# 547/547 [==============================] - 22s 40ms/step - loss: 1.1057 - accuracy: 0.6059 - val_loss: 1.0057 - val_accuracy: 0.6631
# Epoch 15/100
# 547/547 [==============================] - 15s 28ms/step - loss: 1.0939 - accuracy: 0.6092 - val_loss: 1.0126 - val_accuracy: 0.6519
# Epoch 16/100
# 547/547 [==============================] - 15s 28ms/step - loss: 1.0734 - accuracy: 0.6182 - val_loss: 0.9727 - val_accuracy: 0.6690
# Epoch 17/100
# 547/547 [==============================] - 17s 31ms/step - loss: 1.0606 - accuracy: 0.6264 - val_loss: 0.9471 - val_accuracy: 0.6809
# Epoch 18/100
# 547/547 [==============================] - 16s 28ms/step - loss: 1.0552 - accuracy: 0.6256 - val_loss: 0.9752 - val_accuracy: 0.6719
# Epoch 19/100
# 547/547 [==============================] - 15s 28ms/step - loss: 1.0427 - accuracy: 0.6322 - val_loss: 0.9600 - val_accuracy: 0.6717
# Epoch 20/100
# 547/547 [==============================] - 15s 27ms/step - loss: 1.0251 - accuracy: 0.6380 - val_loss: 0.9350 - val_accuracy: 0.6759
# Epoch 21/100
# 547/547 [==============================] - 14s 26ms/step - loss: 1.0261 - accuracy: 0.6398 - val_loss: 0.8992 - val_accuracy: 0.6946
# Epoch 22/100
# 547/547 [==============================] - 15s 27ms/step - loss: 1.0167 - accuracy: 0.6411 - val_loss: 0.9027 - val_accuracy: 0.6924
# Epoch 23/100
# 547/547 [==============================] - 15s 28ms/step - loss: 1.0069 - accuracy: 0.6428 - val_loss: 0.8925 - val_accuracy: 0.6976
# Epoch 24/100
# 547/547 [==============================] - 15s 28ms/step - loss: 0.9946 - accuracy: 0.6480 - val_loss: 0.8928 - val_accuracy: 0.6962
# Epoch 25/100
# 547/547 [==============================] - 15s 28ms/step - loss: 0.9846 - accuracy: 0.6535 - val_loss: 0.8749 - val_accuracy: 0.7025
# Epoch 26/100
# 547/547 [==============================] - 16s 29ms/step - loss: 0.9779 - accuracy: 0.6526 - val_loss: 0.8787 - val_accuracy: 0.7026
# Epoch 27/100
# 547/547 [==============================] - 16s 28ms/step - loss: 0.9737 - accuracy: 0.6591 - val_loss: 0.8866 - val_accuracy: 0.6956
# Epoch 28/100
# 547/547 [==============================] - 16s 28ms/step - loss: 0.9683 - accuracy: 0.6549 - val_loss: 0.8689 - val_accuracy: 0.7039
# Epoch 29/100
# 547/547 [==============================] - 16s 29ms/step - loss: 0.9662 - accuracy: 0.6598 - val_loss: 0.8893 - val_accuracy: 0.6914
# Epoch 30/100
# 547/547 [==============================] - 19s 35ms/step - loss: 0.9623 - accuracy: 0.6619 - val_loss: 0.8935 - val_accuracy: 0.6907
# Epoch 31/100
# 547/547 [==============================] - 19s 35ms/step - loss: 0.9562 - accuracy: 0.6630 - val_loss: 0.8564 - val_accuracy: 0.7067
# Epoch 32/100
# 547/547 [==============================] - 15s 28ms/step - loss: 0.9481 - accuracy: 0.6664 - val_loss: 0.8325 - val_accuracy: 0.7157
# Epoch 33/100
# 547/547 [==============================] - 16s 29ms/step - loss: 0.9435 - accuracy: 0.6690 - val_loss: 0.8343 - val_accuracy: 0.7171
# Epoch 34/100
# 547/547 [==============================] - 17s 31ms/step - loss: 0.9422 - accuracy: 0.6664 - val_loss: 0.8317 - val_accuracy: 0.7200
# Epoch 35/100
# 547/547 [==============================] - 15s 27ms/step - loss: 0.9274 - accuracy: 0.6731 - val_loss: 0.8382 - val_accuracy: 0.7115
# Epoch 36/100
# 547/547 [==============================] - 16s 28ms/step - loss: 0.9295 - accuracy: 0.6715 - val_loss: 0.8464 - val_accuracy: 0.7095
# Epoch 37/100
# 547/547 [==============================] - 14s 26ms/step - loss: 0.9251 - accuracy: 0.6755 - val_loss: 0.8337 - val_accuracy: 0.7129
# Epoch 38/100
# 547/547 [==============================] - 15s 27ms/step - loss: 0.9233 - accuracy: 0.6719 - val_loss: 0.8509 - val_accuracy: 0.7114
# Epoch 39/100
# 547/547 [==============================] - 15s 27ms/step - loss: 0.9141 - accuracy: 0.6774 - val_loss: 0.8292 - val_accuracy: 0.7139
# Epoch 40/100
# 547/547 [==============================] - 15s 27ms/step - loss: 0.9163 - accuracy: 0.6745 - val_loss: 0.8193 - val_accuracy: 0.7218
# Epoch 41/100
# 547/547 [==============================] - 15s 27ms/step - loss: 0.9087 - accuracy: 0.6798 - val_loss: 0.8155 - val_accuracy: 0.7230
# Epoch 42/100
# 547/547 [==============================] - 15s 27ms/step - loss: 0.9047 - accuracy: 0.6843 - val_loss: 0.8149 - val_accuracy: 0.7211
# Epoch 43/100
# 547/547 [==============================] - 16s 29ms/step - loss: 0.8905 - accuracy: 0.6851 - val_loss: 0.8082 - val_accuracy: 0.7221
# Epoch 44/100
# 547/547 [==============================] - 15s 27ms/step - loss: 0.9004 - accuracy: 0.6820 - val_loss: 0.8439 - val_accuracy: 0.7079
# Epoch 45/100
# 547/547 [==============================] - 16s 29ms/step - loss: 0.8946 - accuracy: 0.6822 - val_loss: 0.8077 - val_accuracy: 0.7237
# Epoch 46/100
# 547/547 [==============================] - 16s 29ms/step - loss: 0.8875 - accuracy: 0.6870 - val_loss: 0.8426 - val_accuracy: 0.7101
# Epoch 47/100
# 547/547 [==============================] - 15s 28ms/step - loss: 0.8901 - accuracy: 0.6855 - val_loss: 0.8130 - val_accuracy: 0.7193
# Epoch 48/100
# 547/547 [==============================] - 17s 32ms/step - loss: 0.8840 - accuracy: 0.6871 - val_loss: 0.7951 - val_accuracy: 0.7305
# Epoch 49/100
# 547/547 [==============================] - 15s 28ms/step - loss: 0.8799 - accuracy: 0.6882 - val_loss: 0.7996 - val_accuracy: 0.7326
# Epoch 50/100
# 547/547 [==============================] - 15s 28ms/step - loss: 0.8717 - accuracy: 0.6918 - val_loss: 0.8216 - val_accuracy: 0.7164
# Epoch 51/100
# 547/547 [==============================] - 15s 27ms/step - loss: 0.8753 - accuracy: 0.6900 - val_loss: 0.7957 - val_accuracy: 0.7301
# Epoch 52/100
# 547/547 [==============================] - 15s 27ms/step - loss: 0.8740 - accuracy: 0.6897 - val_loss: 0.7868 - val_accuracy: 0.7345
# Epoch 53/100
# 547/547 [==============================] - 15s 27ms/step - loss: 0.8696 - accuracy: 0.6929 - val_loss: 0.7811 - val_accuracy: 0.7324
# Epoch 54/100
# 547/547 [==============================] - 16s 30ms/step - loss: 0.8709 - accuracy: 0.6921 - val_loss: 0.8107 - val_accuracy: 0.7214
# Epoch 55/100
# 547/547 [==============================] - 20s 36ms/step - loss: 0.8670 - accuracy: 0.6919 - val_loss: 0.7819 - val_accuracy: 0.7369
# Epoch 56/100
# 547/547 [==============================] - 18s 32ms/step - loss: 0.8632 - accuracy: 0.6967 - val_loss: 0.8347 - val_accuracy: 0.7127
# Epoch 57/100
# 547/547 [==============================] - 16s 29ms/step - loss: 0.8706 - accuracy: 0.6914 - val_loss: 0.7812 - val_accuracy: 0.7356
# Epoch 58/100
# 547/547 [==============================] - 16s 29ms/step - loss: 0.8595 - accuracy: 0.6955 - val_loss: 0.8144 - val_accuracy: 0.7187
# CPU times: user 46min 44s, sys: 23min 2s, total: 1h 9min 47s
# Wall time: 15min 17s

# %%
plot_history(history);

# %%
res = model.evaluate(X_test, y_test, verbose = 0)

print(f'The accuracy is {res[1]*100:.3f}% compared to a chance level of {1./len(labels)*100}%')
# Out:
# The accuracy is 72.050% compared to a chance level of 10.0%

# %% [markdown]
# You should observe significant performance improvement
#
# Welcome to the Deep Learning paradigm, where big data makes a significant difference.
#
# But what happens if I can access only a limited amount of pictures? Think about biologists studying rare species. What can they do?
# * To improve the accuracy of a model without much work, we can **generate new data**.
# * The process is called...  **`Data Augmentation`** !
# </details>

# %% [markdown]
# ## (4)  Data augmentation

# %% [markdown]
# *  <b><u>Data Augmentation</u></b>
#     * This technique is widely-used and consists of applying little transformations to the input images without changing their labels: ***mirroring***, ***cropping***, ***intensity changes***, etc...
#     * The _improved performance_ simply results from the CNN training with more images (the original pictures + the "augmented" ones).

# %% [markdown]
#  **Question: using an ImageDataGenerator**
#
# Look at the following code down below
# * The general syntax may look strange but don't worry:
#     * First, focus on the arguments of the *ImageDataGenerator* which define the augmentation techniques that we are using
#     * Then, check the  <a href="https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator">**`ImageDataGenerator`**</a> documentation later

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center = False,
    featurewise_std_normalization = False,
    rotation_range = 10,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = True,
    zoom_range = (0.8, 1.2),
    ) 

datagen.fit(X_train)
datagen

# %%
X_augmented_iterator = datagen.flow(X_train, shuffle=False, batch_size=1)
X_augmented_iterator

# %% [markdown]
#  Always **visualize the augmented images** in order to double-check whether you can still recognize the labels yourself or not

# %%
import numpy as np

for i, (raw_image, augmented_image) in enumerate(zip(X_train, X_augmented_iterator)):
    _, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 2))
    ax1.imshow(raw_image)
    ax2.imshow(augmented_image[0])
    plt.show()
    
    if i > 10:
        break

# %% [markdown]
#  **Remarks**
#
# * Each image from **`X_augmented_iterator`** is an ***augmented image*** of one image located in the original `X_train` image dataset
# * This augmentation process is done once per epoch.
# * During one epoch, the model will:
#     1. *create the augmented version* of each picture from `X_train`,
#     2. for each image of `X_train`, *the model will randomly pick either the original version in `X_train` or its augmented version in `X_augmented_iterator`*
#     3. and the model will be *fitted on the combination of some original images + some augmented images*
#
# ---

# %% [markdown]
#  **Question: what is the validation set when we have augmented images**
#
# * Previously, we used the `validation_split` argument to let the model separate the training set into a Train/Validation split when fitting the model for each epoch.
# * It is not possible to use this kind of Train/Val Split here as **using an image in the training set and its transformation in the validation set is considered `data leakage`** !.
# * Therefore, we have to define the **`validation_data`** manually with the following commands: take time to understand the cell down below:

# %%
from tensorflow.keras.callbacks import EarlyStopping

# The model
model_aug = initialize_model()
model_aug = compile_model(model_aug)

# The data generator
X_tr = X_train[:40000]
y_tr = y_train[:40000]
X_val = X_train[40000:]
y_val = y_train[40000:]
train_flow = datagen.flow(X_tr, y_tr, batch_size = 64)

# The early stopping criterion
es = EarlyStopping(patience = 3)

# The fit
history_aug = model_aug.fit(train_flow, 
                        epochs = 50, 
                        callbacks = [es], 
                        validation_data = (X_val, y_val))
# Out:
# Epoch 1/50
# 625/625 [==============================] - 42s 66ms/step - loss: 1.8821 - accuracy: 0.3052 - val_loss: 1.6503 - val_accuracy: 0.4134
# Epoch 2/50
# 625/625 [==============================] - 24s 39ms/step - loss: 1.6448 - accuracy: 0.3989 - val_loss: 1.4813 - val_accuracy: 0.4857
# Epoch 3/50
# 625/625 [==============================] - 25s 41ms/step - loss: 1.5547 - accuracy: 0.4311 - val_loss: 1.3779 - val_accuracy: 0.5217
# Epoch 4/50
# 625/625 [==============================] - 25s 41ms/step - loss: 1.4879 - accuracy: 0.4593 - val_loss: 1.3675 - val_accuracy: 0.5003
# Epoch 5/50
# 625/625 [==============================] - 25s 40ms/step - loss: 1.4370 - accuracy: 0.4819 - val_loss: 1.2560 - val_accuracy: 0.5686
# Epoch 6/50
# 625/625 [==============================] - 25s 40ms/step - loss: 1.4031 - accuracy: 0.4936 - val_loss: 1.2045 - val_accuracy: 0.5905
# Epoch 7/50
# 625/625 [==============================] - 24s 38ms/step - loss: 1.3705 - accuracy: 0.5077 - val_loss: 1.1659 - val_accuracy: 0.5996
# Epoch 8/50
# 625/625 [==============================] - 24s 39ms/step - loss: 1.3499 - accuracy: 0.5166 - val_loss: 1.1482 - val_accuracy: 0.5940
# Epoch 9/50
# 625/625 [==============================] - 24s 39ms/step - loss: 1.3158 - accuracy: 0.5307 - val_loss: 1.1237 - val_accuracy: 0.6030
# Epoch 10/50
# 625/625 [==============================] - 26s 42ms/step - loss: 1.2965 - accuracy: 0.5355 - val_loss: 1.1318 - val_accuracy: 0.6026
# Epoch 11/50
# 625/625 [==============================] - 23s 37ms/step - loss: 1.2785 - accuracy: 0.5431 - val_loss: 1.1008 - val_accuracy: 0.6046
# Epoch 12/50
# 625/625 [==============================] - 23s 37ms/step - loss: 1.2674 - accuracy: 0.5514 - val_loss: 1.0649 - val_accuracy: 0.6283
# Epoch 13/50
# 625/625 [==============================] - 24s 38ms/step - loss: 1.2566 - accuracy: 0.5491 - val_loss: 1.0381 - val_accuracy: 0.6388
# Epoch 14/50
# 625/625 [==============================] - 23s 37ms/step - loss: 1.2399 - accuracy: 0.5593 - val_loss: 1.0096 - val_accuracy: 0.6473
# Epoch 15/50
# 625/625 [==============================] - 23s 37ms/step - loss: 1.2282 - accuracy: 0.5639 - val_loss: 1.0039 - val_accuracy: 0.6596
# Epoch 16/50
# 625/625 [==============================] - 23s 37ms/step - loss: 1.2186 - accuracy: 0.5705 - val_loss: 0.9892 - val_accuracy: 0.6570
# Epoch 17/50
# 625/625 [==============================] - 23s 37ms/step - loss: 1.2086 - accuracy: 0.5717 - val_loss: 1.0310 - val_accuracy: 0.6312
# Epoch 18/50
# 625/625 [==============================] - 23s 37ms/step - loss: 1.1939 - accuracy: 0.5758 - val_loss: 0.9863 - val_accuracy: 0.6567
# Epoch 19/50
# 625/625 [==============================] - 23s 37ms/step - loss: 1.1869 - accuracy: 0.5799 - val_loss: 0.9694 - val_accuracy: 0.6639
# Epoch 20/50
# 625/625 [==============================] - 23s 37ms/step - loss: 1.1804 - accuracy: 0.5777 - val_loss: 1.0075 - val_accuracy: 0.6405
# Epoch 21/50
# 625/625 [==============================] - 23s 37ms/step - loss: 1.1799 - accuracy: 0.5821 - val_loss: 0.9326 - val_accuracy: 0.6789
# Epoch 22/50
# 625/625 [==============================] - 23s 37ms/step - loss: 1.1658 - accuracy: 0.5875 - val_loss: 0.9843 - val_accuracy: 0.6543
# Epoch 23/50
# 625/625 [==============================] - 23s 37ms/step - loss: 1.1519 - accuracy: 0.5933 - val_loss: 0.9208 - val_accuracy: 0.6822
# Epoch 24/50
# 625/625 [==============================] - 23s 37ms/step - loss: 1.1562 - accuracy: 0.5875 - val_loss: 0.9662 - val_accuracy: 0.6550
# Epoch 25/50
# 625/625 [==============================] - 24s 38ms/step - loss: 1.1513 - accuracy: 0.5901 - val_loss: 0.9710 - val_accuracy: 0.6546
# Epoch 26/50
# 625/625 [==============================] - 24s 38ms/step - loss: 1.1381 - accuracy: 0.6004 - val_loss: 0.9282 - val_accuracy: 0.6718

# %% [markdown]
#  **Question: How did the model with an augmented dataset perform?**
#
# Let's plot the previous and current run histories. What do you think of the data augmentation?

# %%
axs = plot_history(history_aug, exp_name = 'data_augmentation')
plot_history(history ,axs = axs, exp_name='baseline')
plt.show()

# %%
res_1 = model.evaluate(X_test, y_test, verbose = 0)

res_2 = model_aug.evaluate(X_test, y_test, verbose = 1)

print(f'Accuracy without data augmentation {res_1[1]*100:.2f}%')
print(f'Accuracy with data augmentation {res_2[1]*100:.2f}%')
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9372 - accuracy: 0.6715
# Accuracy without data augmentation 72.05%
# Accuracy with data augmentation 67.15%
